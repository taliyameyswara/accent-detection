.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/synthesized2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/estonian2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/cantonese20.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/romanian20.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french27.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/macedonian7.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/japanese26.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english166.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english122.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/kikuyu1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/macedonian24.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english251.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english528.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english340.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish21.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/hungarian3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish83.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic68.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/bulgarian11.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english222.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english289.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish61.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english249.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english570.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/japanese4.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/tatar1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/ukrainian2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/macedonian2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/japanese25.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish41.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/bulgarian14.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish73.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/catalan1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic99.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/chittagonian1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english377.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/korean38.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/german19.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/korean13.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english87.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish90.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish16.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/afrikaans3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english51.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english56.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/amharic11.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english353.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english137.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/croatian8.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/tigrigna7.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/hausa8.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish116.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english531.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english293.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english355.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/hindi2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english233.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/georgian1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/sa'a1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/portuguese39.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/hindi4.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish66.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/hindi3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english523.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/korean25.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish55.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/turkish12.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/croatian4.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french8.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/somali5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/turkish11.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english347.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/tamil1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/german3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/rwanda1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/latvian3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic48.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/vietnamese18.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic90.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/polish13.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/italian33.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french58.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish62.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish149.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/cantonese11.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/cantonese23.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/mongolian5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english294.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english283.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english313.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic19.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/russian38.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/macedonian11.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english252.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english276.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/dutch44.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english479.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english30.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english48.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/amharic6.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/italian16.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english348.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english203.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english379.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english97.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/azerbaijani1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/turkish33.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english329.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english256.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/serbian1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/mandarin20.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/taiwanese8.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english458.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english529.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/farsi7.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english4.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english90.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish38.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/rotuman1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish81.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english419.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish52.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english33.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/portuguese36.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/yoruba3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/mandarin13.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/kannada1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/cantonese8.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english149.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/punjabi8.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english388.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french26.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english537.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french63.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/mandarin12.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/turkish7.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic74.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic96.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english440.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/serbian18.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/luo1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/pashto4.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/italian30.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/danish1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/swedish12.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french35.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/macedonian12.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/bulgarian7.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/mandarin14.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/dutch5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/afrikaans5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english513.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic16.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/moore1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/kazakh2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english324.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french45.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/georgian5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english411.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/korean5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/synthesized3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/mandarin34.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/bengali16.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english246.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english99.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english349.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english553.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/greek9.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/portuguese7.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/dutch39.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/kurdish2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/zulu1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/french5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/uyghur2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/german4.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english9.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/dutch22.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english84.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/hindi10.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/korean35.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/polish16.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish70.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/danish6.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english269.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/arabic12.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/swedish3.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/dutch46.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/satawalese2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/japanese20.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english202.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/krio6.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/russian40.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english410.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/krio5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english179.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/armenian5.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/polish10.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/ewe1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish155.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english502.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/agni1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/spanish30.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/marathi1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english215.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english547.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english261.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/tswana2.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english572.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english408.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/portuguese17.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english167.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/english374.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/nuer1.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/kurdish8.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/amharic7.mp3
# /kaggle/input/speech-accent-archive/recordings/recordings/jola1.mp3

# %% [markdown]
# # 🎙️🗣️ **Speech Accent Classification using CNN** 🎙️🗣️
# In this project, we are going to classify speech accents from audio recordings using Convolutional Neural Networks (CNN). Classifying speech accents can be useful for things like speech recognition and language learning.

# %% [markdown]
# ## 🎯 **Dataset Overview**
# The dataset we use has audio files of people speaking with different accents. Here's an overview of the dataset:
#
# **🎵 Audio Files:**
# - Each file contains a recording of a person speaking, with a specific accent.
# - All the audio files are in the .mp3 format, which is common for audio data.
#
# 🏷️ **Labels:**
# - Each audio file is labeled with the accent it represents, the label is on the filename.
#
# 🛠️ **Challenges:**
# - The audio files have some challenges:
#   - **Noise**: Some files have background noise that makes it harder to classify the accent.
#   - **Length**: The length of the audio files varies, which can affect how we process the data.
#   - **Quality**: The quality of the recordings may differ, which adds complexity to the task.

# %% [markdown]
# ## ⚙️ **Project Workflow**
#
# This notebook will follow a step-by-step approach to solve the accent classification problem using CNN. The main steps are:
#
# ### 🗂️ 1. Loading and Exploring the Dataset:
# First, we will load the audio files and take a look at the data to understand how many samples we have and what the accent distribution looks like.
#
# ### 🎛️ 2. Feature Extraction:
# We cannot use raw audio data directly, so we need to extract features like Mel-frequency cepstral coefficients (MFCCs) or spectrograms from the audio files. These features will help the model better understand the audio.
#
# ### ✨ 3. Data Preprocessing:
# Once we have the features, we will preprocess the data. This includes normalizing the data and making sure it's ready for training. We may also do some data augmentation to improve the model's ability to generalize.
#
# ### 🧠 4. Model Selection and Training:
# Next, we will choose a CNN model and train it using the features we extracted. CNNs are good for image-like data, and audio features can be treated in a similar way to images.
#
# ### 📊 5. Evaluation and Optimization:
# After training, we will evaluate how well our model performs. We will use metrics like accuracy to check how good the model is at classifying accents. If needed, we will improve the model by tuning hyperparameters and making other adjustments.

# %% [markdown]
# # **🚀 Project Steps Starts! 🚀**

# %% [markdown]
# # **🗃️ Libraries Imports**
# The libraries used in the project and the steps taken to classify audio files. Each library plays a crucial role in data manipulation, feature extraction, and model building.

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
import tensorflow as tf
import librosa
import os
import soundfile as sf
import torch, torchaudio
import torchaudio.functional as f
import re
from scipy.signal import resample
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **📊 Data Loading and Initial Exploration 🧩**
# We start by loading the dataset, which contains information about audio files and their corresponding classes. 📂

# %%
dir = '/kaggle/input/speech-accent-archive/recordings/recordings'
audio_list = os.listdir(dir)
print('Dataset length')
len(audio_list)
# Out:
# Dataset length
# 2138

# %%
df = pd.DataFrame()
df['speech'] = audio_list

labels = [re.sub(r'\d+\.mp3$', '', audio) for audio in audio_list]

df = pd.DataFrame({
    'speech': audio_list,
    'labels': labels
})

df.head()
# Out:
#            speech   labels
# 0   spanish47.mp3  spanish
# 1  english220.mp3  english
# 2    arabic64.mp3   arabic
# 3    russian7.mp3  russian
# 4     dutch36.mp3    dutch

# %% [markdown]
# ## **🔍 Class Distribution 📊**

# %%
# count the all label
df['labels'].value_counts()
# Out:
# labels
# english           579
# spanish           162
# arabic            102
# mandarin           65
# french             63
#                  ...
# luxembourgeois      1
# wu                  1
# shan                1
# faroese             1
# jola                1
# Name: count, Length: 200, dtype: int64

# %%
# data analysis of all label
sns.countplot(x = df['labels'], data=df)
# Out:
# <Axes: xlabel='labels', ylabel='count'>

# %% [markdown]
# As we can see, the data is imbalance. We can fix it later, after extraction

# %% [markdown]
# # 🎼 **Feature Extraction using MFCC** 🎶
# For accurate classification, we need to extract features from the raw audio data using MFCC (Mel-frequency cepstral coefficients)

# %% [markdown]
# ## **🔨 MFCC Feature Extraction 🔨**
# We use the librosa library to extract MFCC features from each audio file. 🎵
# MFCC helps capture the sound features that will be used for classification. The features are extracted, and mean values are computed for simplicity. 🧠

# %%
target_sample_rate = 44100  # Target sample rate for the audio

def extract_features(audio_file, n_fft=128, hop_length=32, n_mfcc=13):
    # Read the audio file using soundfile library
    y, sr = sf.read(audio_file)

    # Check if the sample rate is different from the target sample rate
    if sr != target_sample_rate:
        # Resample the audio to the target sample rate
        y = resample(y, int(len(y) * target_sample_rate / sr))
        sr = target_sample_rate

    # Extract the first 10 seconds of audio (assuming the file is long enough)
    samples_10_sec = target_sample_rate * 5   # 10 seconds of audio at the target sample rate
    y_10_sec = y[:samples_10_sec]  # Slice the audio to get the first 10 seconds

    # Extract Mel-Frequency Cepstral Coefficients (MFCCs) from the audio
    mfccs = librosa.feature.mfcc(y = y_10_sec, sr=sr, n_mfcc=n_mfcc)

    # Normalize the MFCCs (mean = 0, standard deviation = 1)
    mfccs_normalized = (mfccs - np.mean(mfccs)) / np.std(mfccs)

    return mfccs  # Return the MFCC features

# %%
data = []  # Empty list to store audio features and labels

# Loop through each audio file in the audio_list
for audio in audio_list:
    # Create the full path to the audio file
    audio_path = dir + "/" + audio

    # Extract features from the audio file (using the extract_features function)
    feature = extract_features(audio_path)

    # Create the label by removing numbers from the file name and removing the .mp3 extension
    label = re.sub(r'\d+', '', audio[:-4])  # Remove digits from the file name using regex

    # Append the feature and label as a tuple to the data list
    data.append((feature, label))

# %% [markdown]
# ## 📊 **Converting to Dataframe** 🖼️

# %%
separated_data = []  # List to store dictionaries with MFCC features for each audio
label_arr = []  # List to store the labels for each audio file

# Loop through each feature-label pair in the data
for f, l in data:
    # Create a dictionary of MFCCs by calculating the mean of each MFCC coefficient across time
    # The dictionary key is the MFCC name (e.g., 'MFCC_1', 'MFCC_2', etc.)
    mfcc_dict = {f'MFCC_{i+1}': np.mean(f[i]) for i in range(f.shape[0])}

    # Append the label to the label_arr list
    label_arr.append(l)

    # Append the dictionary of MFCCs to the separated_data list
    separated_data.append(mfcc_dict)

# %%
# Convert the list of MFCC dictionaries into a Pandas DataFrame
df_new = pd.DataFrame(separated_data)

# Add the labels as a new column in the DataFrame
df_new['label'] = label_arr

# Display the first few rows of the DataFrame to check the data
df_new.head()
# Out:
#        MFCC_1      MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6  \
# 0 -396.429650  166.844056 -26.592988  19.675905   9.440444 -15.084824
# 1 -315.374044  142.936627 -65.129223   5.381406   7.206723 -10.902184
# 2 -312.487482  125.400791  16.526782  34.864688   4.974225  20.645630
# 3 -352.076937   93.506333 -14.929739  15.153140 -12.022427   2.648440
# 4 -374.195575  104.946241   5.720582  33.258716   3.137331  12.003813
#
#       MFCC_7     MFCC_8     MFCC_9    MFCC_10    MFCC_11   MFCC_12   MFCC_13  \
# 0  12.037416  -6.700806  -6.122482   3.113079 -12.255310 -0.133417 -1.442457
# 1   3.717204 -26.519754  -1.514703  15.668458 -14.213459 -2.694849 -2.021795
# 2  -0.804459   8.526824 -12.421622  -2.128536  -2.235220  2.025745 -0.397765
# 3  -8.378778   3.260275 -23.195564   0.136694  -7.167136 -1.318334  0.569017
# 4  -2.735049   8.224015  -2.002304   1.043862  -1.255645 -3.336594 -3.344836
#
#      label
# 0  spanish
# 1  english
# 2   arabic
# 3  russian
# 4    dutch

# %%
# Check for any missing (null) values in the DataFrame and count them
df_new.isnull().sum()
# Out:
# MFCC_1     0
# MFCC_2     0
# MFCC_3     0
# MFCC_4     0
# MFCC_5     0
# MFCC_6     0
# MFCC_7     0
# MFCC_8     0
# MFCC_9     0
# MFCC_10    0
# MFCC_11    0
# MFCC_12    0
# MFCC_13    0
# label      0
# dtype: int64

# %%
# Print the length of the DataFrame before removing missing values
print(len(df_new))

# Remove rows with missing (null) values from the DataFrame
df_cleaned = df_new.dropna()

# Print the length of the DataFrame after removing missing values
print(len(df_cleaned))
# Out:
# 2138
# 2138

# %%
# Get the count of each unique value (accent label) in the 'label' column
accent_counts = df_cleaned['label'].value_counts()

# Print the counts of each accent label
print(accent_counts)
# Out:
# label
# english           579
# spanish           162
# arabic            102
# mandarin           65
# french             63
#                  ...
# luxembourgeois      1
# wu                  1
# shan                1
# faroese             1
# jola                1
# Name: count, Length: 200, dtype: int64

# %% [markdown]
# # **🧹 Data Preprocessing 🧹**

# %% [markdown]
# ## **🌈Oversampling Dataset🌈**
# From the previous step, we observed that the dataset is imbalanced, meaning some accent labels appear more frequently than others. To address this issue, we can use oversampling techniques to balance the dataset by increasing the number of samples from underrepresented classes.

# %%
# Find the accent label with the most samples (largest group)
largest_accent = accent_counts.idxmax()

# Get the count of the largest group (most samples)
max_count = accent_counts.max()

# Initialize an empty list to store the oversampled data
oversampled_data = []

# Loop through each accent label and its count
for accent, count in accent_counts.items():
    # If the accent is not the largest group and has more than 30 samples
    if accent != largest_accent and count > 30:
        # Get the data for the current accent
        accent_data = df_cleaned[df_cleaned['label'] == accent]

        # Oversample the accent group to match the size of the largest group
        oversampled_accent = accent_data.sample(n=max_count, replace=True, random_state=42)

        # Append the oversampled data for this accent
        oversampled_data.append(oversampled_accent)
    # If the accent is the largest group, do not oversample, just append it as is
    elif accent == largest_accent:
        oversampled_data.append(df_cleaned[df_cleaned['label'] == accent])

# Combine the oversampled data to form a new balanced DataFrame
balanced_df = pd.concat(oversampled_data)

# %%
# Shuffle the rows of the balanced DataFrame to randomize the order of the samples
df_shuffled = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Display the first few rows of the shuffled DataFrame
df_shuffled.head()
# Out:
#        MFCC_1      MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6  \
# 0 -330.133270  162.584548 -21.769244  -5.104358 -10.122103  -3.721666
# 1 -341.789532  132.619574   0.601831  47.681482   9.711360  -0.294174
# 2 -421.250658   95.664571 -14.816503  18.264395 -11.243732  12.782665
# 3 -319.118536   93.952870  12.912545  49.877915  -4.416125  12.896248
# 4 -358.332221  122.910272   7.424896  32.483800  -1.138527  10.564397
#
#       MFCC_7     MFCC_8     MFCC_9    MFCC_10    MFCC_11    MFCC_12  \
# 0   9.591475 -26.680993 -13.058319  -0.143801 -15.624143   2.044865
# 1  -7.281345 -13.446461 -19.497527 -19.740662  -3.158329  -7.271355
# 2 -21.186349   2.590755  -4.938478 -15.970697 -11.245938 -10.957044
# 3 -19.733087 -10.902267  -8.214854  -1.831642 -19.086026 -11.696086
# 4  -3.145841   8.001234  -4.130050   8.179388  -0.898651   0.960461
#
#      MFCC_13    label
# 0   1.791991   german
# 1  -6.388170   arabic
# 2 -12.194119   korean
# 3  -7.329425  turkish
# 4  -2.046598  russian

# %%
# Separate the target variable (label) into y
y = df_shuffled["label"]

# Separate the features (all columns except 'label') into x
x = df_shuffled.drop('label', axis=1)

# %% [markdown]
# ## **🌟 Label Encoding 🌟**
#
# To prepare the labels, we need to convert the categorical label values (accents) into numeric values. For this, we use the `LabelEncoder` from `sklearn`.
#
# Here is how the encoding process works:
#
# - **LabelEncoder** converts each unique label (such as an accent name) into a corresponding integer value.
# - The mapping of original labels to numeric encoded values is displayed below.
#
# **Label Mapping:**
#
# We map the original labels to their encoded values, so that the machine learning model can interpret them correctly.

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder to encode the labels
label_encoder = LabelEncoder()

# Fit and transform the target labels (y) into encoded labels
encoded_labels = label_encoder.fit_transform(y)

# Create a dictionary to map original labels to encoded labels
label_mapping = {label: encoded_label for label, encoded_label in zip(y, encoded_labels)}

# Print the mapping of labels to encoded values
class_label = []  # Initialize an empty list to store the original labels
print("Label mapping:")
for label, encoded_label in label_mapping.items():
    class_label.append(label)  # Add original label to the list
    print(f"{label}: {encoded_label}")  # Print the original label and its corresponding encoded value

# %% [markdown]
# # **✂️ Splitting the Data ✂️**
# We split the data into training and test sets to evaluate the model performance. 📊
#
# 80% of the data is used for training the model, and 20% is reserved for testing. 🧑‍🔬

# %%
from sklearn.model_selection import train_test_split

# Convert the feature columns (excluding 'label') from the shuffled DataFrame into a NumPy array
X = np.array(df_shuffled.drop('label', axis=1).values)

# Extract the target labels ('label' column) from the shuffled DataFrame into a NumPy array
y = df_shuffled['label'].values

# Initialize the LabelEncoder to convert categorical labels into numeric values
label_encoder = LabelEncoder()

# Fit the encoder to the labels and transform the labels into numeric values (encoded labels)
y_encoded = label_encoder.fit_transform(y)

# Convert the numeric labels into one-hot encoded format (binary matrix representation)
y_onehot = to_categorical(y_encoded)

# Split the data into training and testing sets (80% for training, 20% for testing)
# The features (X) and one-hot encoded labels (y_onehot) are split
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42)

# %% [markdown]
# # **🏋️‍♂️ Model Training with CNN🎓**
# Now, we fit our model to the training data.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D

# Function to build the CNN model for accent classification
def build_cnn_model(input_shape):
    # Initialize the Sequential model (a linear stack of layers)
    model = Sequential()

    # Add the first 1D convolutional layer with 32 filters, a kernel size of 3, and ReLU activation function
    # input_shape is the shape of each input sample (number of features, 1 for a single channel)
    model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape))

    # Add a MaxPooling layer with pool size of 2 to downsample the output of the previous layer
    model.add(MaxPooling1D(pool_size=2))

    # Add the second 1D convolutional layer with 64 filters and kernel size of 3, using ReLU activation
    model.add(Conv1D(64, 3, activation='relu'))

    # Add another MaxPooling layer to further downsample the feature map
    model.add(MaxPooling1D(2))

    # Flatten the 2D output from the last MaxPooling layer into a 1D vector
    model.add(Flatten())

    # Add a fully connected (Dense) layer with 128 neurons and ReLU activation function
    model.add(Dense(128, activation='relu'))

    # Add Dropout layer to reduce overfitting by randomly setting 50% of the input units to zero during training
    model.add(Dropout(0.5))

    # Add the final output layer with as many neurons as there are classes (y_train.shape[1]) and softmax activation
    # Softmax is used for multi-class classification, converting the outputs into probabilities
    model.add(Dense(y_train.shape[1], activation='softmax'))

    # Compile the model with Adam optimizer, categorical crossentropy loss function, and accuracy metric
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

    # Return the built model
    return model

# Define the input shape for the model: (number of features, 1) for a single channel (e.g., MFCC features)
input_shape = (X_train.shape[1], 1)

# Build the CNN model using the defined input shape
model = build_cnn_model(input_shape)

# Train the model using the training data (X_train, y_train) and validate it using the test data (X_test, y_test)
# The model will train for 150 epochs with a batch size of 32, and display progress at the end of each epoch
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/150
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 189/189 - 2s - 13ms/step - accuracy: 0.1108 - loss: 3.1967 - val_accuracy: 0.1853 - val_loss: 2.4480
# Epoch 2/150
# 189/189 - 1s - 3ms/step - accuracy: 0.1716 - loss: 2.4368 - val_accuracy: 0.2530 - val_loss: 2.3145
# Epoch 3/150
# 189/189 - 1s - 3ms/step - accuracy: 0.2016 - loss: 2.3652 - val_accuracy: 0.2942 - val_loss: 2.2455
# Epoch 4/150
# 189/189 - 1s - 3ms/step - accuracy: 0.2327 - loss: 2.2833 - val_accuracy: 0.3181 - val_loss: 2.1464
# Epoch 5/150
# 189/189 - 1s - 3ms/step - accuracy: 0.2624 - loss: 2.1945 - val_accuracy: 0.3181 - val_loss: 2.0944
# Epoch 6/150
# 189/189 - 1s - 3ms/step - accuracy: 0.2928 - loss: 2.1132 - val_accuracy: 0.3685 - val_loss: 1.9800
# Epoch 7/150
# 189/189 - 1s - 3ms/step - accuracy: 0.3205 - loss: 2.0288 - val_accuracy: 0.4343 - val_loss: 1.8512
# Epoch 8/150
# 189/189 - 1s - 3ms/step - accuracy: 0.3426 - loss: 1.9322 - val_accuracy: 0.4482 - val_loss: 1.7658
# Epoch 9/150
# 189/189 - 1s - 3ms/step - accuracy: 0.3754 - loss: 1.8608 - val_accuracy: 0.4615 - val_loss: 1.7136
# Epoch 10/150
# 189/189 - 1s - 3ms/step - accuracy: 0.4057 - loss: 1.7799 - val_accuracy: 0.5193 - val_loss: 1.5624
# Epoch 11/150
# 189/189 - 1s - 3ms/step - accuracy: 0.4237 - loss: 1.7089 - val_accuracy: 0.5611 - val_loss: 1.4563
# Epoch 12/150
# 189/189 - 1s - 3ms/step - accuracy: 0.4484 - loss: 1.6176 - val_accuracy: 0.5896 - val_loss: 1.3809
# Epoch 13/150
# 189/189 - 1s - 3ms/step - accuracy: 0.4664 - loss: 1.5758 - val_accuracy: 0.5950 - val_loss: 1.3272
# Epoch 14/150
# 189/189 - 1s - 3ms/step - accuracy: 0.4888 - loss: 1.4903 - val_accuracy: 0.6288 - val_loss: 1.2532
# Epoch 15/150
# 189/189 - 1s - 3ms/step - accuracy: 0.5076 - loss: 1.4305 - val_accuracy: 0.6481 - val_loss: 1.1863
# Epoch 16/150
150
# 189/189 - 1s - 3ms/step - accuracy: 0.8404 - loss: 0.4506 - val_accuracy: 0.9462 - val_loss: 0.1996
# Epoch 137/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8397 - loss: 0.4639 - val_accuracy: 0.9416 - val_loss: 0.1952
# Epoch 138/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8480 - loss: 0.4313 - val_accuracy: 0.9495 - val_loss: 0.1948
# Epoch 139/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8303 - loss: 0.4785 - val_accuracy: 0.9250 - val_loss: 0.2350
# Epoch 140/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8421 - loss: 0.4441 - val_accuracy: 0.9236 - val_loss: 0.2599
# Epoch 141/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8445 - loss: 0.4554 - val_accuracy: 0.9449 - val_loss: 0.1994
# Epoch 142/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8535 - loss: 0.4001 - val_accuracy: 0.9456 - val_loss: 0.2222
# Epoch 143/150
# 189/189 - 0s - 3ms/step - accuracy: 0.8464 - loss: 0.4363 - val_accuracy: 0.9456 - val_loss: 0.2045
# Epoch 144/150
# 189/189 - 0s - 2ms/step - accuracy: 0.8593 - loss: 0.4002 - val_accuracy: 0.9449 - val_loss: 0.1994
# Epoch 145/150
# 189/189 - 0s - 3ms/step - accuracy: 0.8430 - loss: 0.4513 - val_accuracy: 0.9442 - val_loss: 0.2153
# Epoch 146/150
# 189/189 - 0s - 3ms/step - accuracy: 0.8444 - loss: 0.4349 - val_accuracy: 0.9396 - val_loss: 0.2136
# Epoch 147/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8563 - loss: 0.4156 - val_accuracy: 0.9436 - val_loss: 0.1952
# Epoch 148/150
# 189/189 - 0s - 3ms/step - accuracy: 0.8497 - loss: 0.4245 - val_accuracy: 0.9502 - val_loss: 0.1848
# Epoch 149/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8489 - loss: 0.4304 - val_accuracy: 0.9515 - val_loss: 0.1836
# Epoch 150/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8517 - loss: 0.4312 - val_accuracy: 0.9495 - val_loss: 0.1900

# %% [markdown]
# # **📈Plotting Accuracy & Loss📉**

# %%
import matplotlib.pyplot as plt

# Get the metrics from the history object
metrics = history.history

# Create a figure with smaller subplots placed side by side
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

# Plot Accuracy
axs[0].plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))
axs[0].set_title("Accuracy CNN")
axs[0].set_ylim([0, 100])
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Accuracy")
axs[0].legend(['accuracy', 'val_accuracy'])

# Plot Loss
axs[1].plot(history.epoch, np.array(metrics['loss']), np.array(metrics['val_loss']))
axs[1].set_title("Loss CNN")
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Loss")
axs[1].legend(['loss', 'val_loss'])

# Display the plots
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Get the predicted probabilities for each class from the model
y_pred_probs = model.predict(X_test)

# Convert the predicted probabilities into class labels by selecting the index with the highest probability
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Convert the one-hot encoded true labels (y_test) into class labels by selecting the index with the 1 in each one-hot vector
y_true = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import classification_report

# Define the list of class names corresponding to the labels
class_names = [
    "Arabic", "Dutch", "English", "French", "German",
    "Italian", "Korean", "Mandarin", "Polish", "Portuguese",
    "Russian", "Spanish", "Turkish"
]

# Generate the classification report, which provides metrics like precision, recall, f1-score
# for each class in the dataset
report = classification_report(y_true, y_pred, target_names=class_names)

# Print the classification report to see the evaluation results
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       0.92      0.97      0.94       141
#        Dutch       0.99      1.00      1.00       119
#      English       0.82      0.60      0.69       107
#       French       0.92      0.99      0.95       107
#       German       1.00      1.00      1.00       114
#      Italian       0.99      1.00      1.00       119
#       Korean       0.96      0.96      0.96       111
#     Mandarin       0.94      0.98      0.96       124
#       Polish       0.97      1.00      0.99       109
#   Portuguese       0.97      1.00      0.99       104
#      Russian       0.96      1.00      0.98       110
#      Spanish       0.87      0.83      0.85       124
#      Turkish       0.99      1.00      1.00       117
#
#     accuracy                           0.95      1506
#    macro avg       0.95      0.95      0.95      1506
# weighted avg       0.95      0.95      0.95      1506

# %%
# Save the trained model to a file
model.save('cnn.h5')

# Load the saved model from the file
from tensorflow.keras.models import load_model
model = load_model('cnn.h5')

# %%
model.save('cnn_model.keras')  # TensorFlow will use the SavedModel format by default

# %% [markdown]
# # **✨Hyperparameter Tuning for Improving Model Performance✨**
#
# After training the model, the results were not satisfactory. To improve the performance, we will perform **hyperparameter tuning**. This process involves adjusting the model's hyperparameters to find the best configuration that results in better accuracy and generalization.
#
# Hyperparameters, such as the learning rate, batch size, number of layers, and number of epochs, play a crucial role in the model's ability to learn from data and make accurate predictions. By fine-tuning these values, we aim to optimize the model's performance.
#
# Let's start the hyperparameter tuning process to improve our model's results.

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras_tuner import HyperModel

# Define a class that inherits from HyperModel to enable hyperparameter tuning
class CNNHyperModel(HyperModel):
    def __init__(self, input_shape, num_classes):
        # Initialize the model with input shape and number of classes
        self.input_shape = input_shape  # Shape of the input data (e.g., number of features in each sample)
        self.num_classes = num_classes  # Number of classes (i.e., output size)

    def build(self, hp):
        # Build the model using the provided hyperparameters (hp)
        model = Sequential()

        # First Convolutional Layer
        model.add(Conv1D(
            filters=hp.Int('filters1', min_value=32, max_value=128, step=32),  # Tune the number of filters
            kernel_size=hp.Int('kernel_size1', min_value=2, max_value=5, step=1),  # Tune the kernel size
            activation='relu',  # Use ReLU activation
            padding='same',  # Padding to maintain the input size
            input_shape=self.input_shape  # Input shape from the data
        ))
        model.add(MaxPooling1D(pool_size=2))  # MaxPooling to reduce the spatial size

        # Second Convolutional Layer
        model.add(Conv1D(
            filters=hp.Int('filters2', min_value=64, max_value=256, step=32),  # Tune the number of filters
            kernel_size=hp.Int('kernel_size2', min_value=2, max_value=5, step=1),  # Tune the kernel size
            activation='relu',  # Use ReLU activation
            padding='same'  # Padding to maintain the input size
        ))
        model.add(MaxPooling1D(pool_size=2))  # MaxPooling to reduce the spatial size

        # Flatten the output of the convolutional layers to feed into fully connected layers
        model.add(Flatten())

        # Fully connected layer (Dense Layer)
        model.add(Dense(
            hp.Int('dense_units', min_value=64, max_value=256, step=64),  # Tune the number of units in the dense layer
            activation='relu'  # Use ReLU activation for the dense layer
        ))

        # Dropout layer to prevent overfitting (randomly drops some of the units during training)
        model.add(Dropout(hp.Float('dropout_rate', min_value=0.2, max_value=0.5, step=0.1)))  # Tune the dropout rate

        # Output layer with softmax activation (for multi-class classification)
        model.add(Dense(self.num_classes, activation='softmax'))

        # Compile the model with Adam optimizer and categorical crossentropy loss function
        model.compile(
            optimizer=Adam(
                hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')  # Tune the learning rate with log sampling
            ),
            loss='categorical_crossentropy',  # Suitable loss function for multi-class classification
            metrics=['accuracy']  # Track accuracy during training
        )

        # Return the compiled model
        return model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# EarlyStopping callback stops training when the model stops improving
early_stopper = EarlyStopping(
    monitor='val_loss',  # Monitors the validation loss to check for improvement
    patience=10,  # Number of epochs to wait for improvement before stopping
    verbose=1,  # Prints a message when the training is stopped early
    restore_best_weights=True  # Restores the weights from the epoch with the best validation loss
)

# ReduceLROnPlateau callback reduces the learning rate when the model stops improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Monitors the validation loss to check for improvement
    factor=0.5,  # Multiplies the current learning rate by this factor (0.5) when the loss plateaus
    patience=5,  # Number of epochs to wait before reducing the learning rate
    verbose=1,  # Prints a message when the learning rate is reduced
    min_lr=1e-6  # Minimum learning rate the optimizer can reach, prevents it from going too low
)

# %%
best_model = tuner.get_best_models(num_models=1)[0]
loss, accuracy = best_model.evaluate(X_test, y_test)
print("Best model accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1414
# Best model accuracy: 96.35%

# %%
# Creating CNN model with the optimized parameter from the start
def create_cnn_model(input_shape, num_classes):
    model = Sequential()

    model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='same', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Flatten())

    model.add(Dense(256, activation='relu'))

    model.add(Dropout(0.2))

    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=0.0011876), loss='categorical_crossentropy', metrics=['accuracy'])

    return model

best_model = create_cnn_model(input_shape, num_classes)

# Train data again from the start
history = best_model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/150
# 189/189 - 2s - 13ms/step - accuracy: 0.1209 - loss: 3.3524 - val_accuracy: 0.1394 - val_loss: 2.5121
# Epoch 2/150
# 189/189 - 1s - 5ms/step - accuracy: 0.1501 - loss: 2.4807 - val_accuracy: 0.1600 - val_loss: 2.4527
# Epoch 3/150
# 189/189 - 1s - 4ms/step - accuracy: 0.1784 - loss: 2.4125 - val_accuracy: 0.2357 - val_loss: 2.3584
# Epoch 4/150
# 189/189 - 1s - 4ms/step - accuracy: 0.2239 - loss: 2.3012 - val_accuracy: 0.2855 - val_loss: 2.1662
# Epoch 5/150
# 189/189 - 1s - 4ms/step - accuracy: 0.2880 - loss: 2.1492 - val_accuracy: 0.3792 - val_loss: 1.9822
# Epoch 6/150
# 189/189 - 1s - 4ms/step - accuracy: 0.3759 - loss: 1.9073 - val_accuracy: 0.4615 - val_loss: 1.7450
# Epoch 7/150
# 189/189 - 1s - 4ms/step - accuracy: 0.4807 - loss: 1.5861 - val_accuracy: 0.5843 - val_loss: 1.3524
# Epoch 8/150
# 189/189 - 1s - 4ms/step - accuracy: 0.5909 - loss: 1.2770 - val_accuracy: 0.6580 - val_loss: 1.0779
150
# 189/189 - 1s - 4ms/step - accuracy: 0.9890 - loss: 0.0418 - val_accuracy: 0.9708 - val_loss: 0.2459
# Epoch 129/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9910 - loss: 0.0225 - val_accuracy: 0.9622 - val_loss: 0.3142
# Epoch 130/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9851 - loss: 0.0554 - val_accuracy: 0.9655 - val_loss: 0.3103
# Epoch 131/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9897 - loss: 0.0342 - val_accuracy: 0.9675 - val_loss: 0.3140
# Epoch 132/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9834 - loss: 0.0594 - val_accuracy: 0.9602 - val_loss: 0.2973
# Epoch 133/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9839 - loss: 0.0593 - val_accuracy: 0.9708 - val_loss: 0.2334
# Epoch 134/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9839 - loss: 0.0544 - val_accuracy: 0.9681 - val_loss: 0.2977
# Epoch 135/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9877 - loss: 0.0335 - val_accuracy: 0.9668 - val_loss: 0.2898
# Epoch 136/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9864 - loss: 0.0557 - val_accuracy: 0.9701 - val_loss: 0.2895
# Epoch 137/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9870 - loss: 0.0472 - val_accuracy: 0.9628 - val_loss: 0.3787
# Epoch 138/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9846 - loss: 0.0613 - val_accuracy: 0.9714 - val_loss: 0.3195
# Epoch 139/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9909 - loss: 0.0330 - val_accuracy: 0.9714 - val_loss: 0.3401
# Epoch 140/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9914 - loss: 0.0325 - val_accuracy: 0.9734 - val_loss: 0.2543
# Epoch 141/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9829 - loss: 0.0691 - val_accuracy: 0.9695 - val_loss: 0.2983
# Epoch 142/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9889 - loss: 0.0454 - val_accuracy: 0.9681 - val_loss: 0.2968
# Epoch 143/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9781 - loss: 0.0965 - val_accuracy: 0.9708 - val_loss: 0.3054
# Epoch 144/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9869 - loss: 0.0425 - val_accuracy: 0.9688 - val_loss: 0.2997
# Epoch 145/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9870 - loss: 0.0388 - val_accuracy: 0.9681 - val_loss: 0.3145
# Epoch 146/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9867 - loss: 0.0476 - val_accuracy: 0.9695 - val_loss: 0.2730
# Epoch 147/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9811 - loss: 0.0661 - val_accuracy: 0.9728 - val_loss: 0.2556
# Epoch 148/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9862 - loss: 0.0518 - val_accuracy: 0.9688 - val_loss: 0.2757
# Epoch 149/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9847 - loss: 0.0645 - val_accuracy: 0.9695 - val_loss: 0.3264
# Epoch 150/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9932 - loss: 0.0282 - val_accuracy: 0.9728 - val_loss: 0.3129

# %%
import matplotlib.pyplot as plt

# Get the metrics from the history object
metrics = history.history

# Create a figure with smaller subplots placed side by side
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

# Plot Accuracy
axs[0].plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))
axs[0].set_title("Accuracy CNN")
axs[0].set_ylim([0, 100])
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Accuracy")
axs[0].legend(['accuracy', 'val_accuracy'])

# Plot Loss
axs[1].plot(history.epoch, np.array(metrics['loss']), np.array(metrics['val_loss']))
axs[1].set_title("Loss CNN")
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Loss")
axs[1].legend(['loss', 'val_loss'])

# Display the plots
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Predict the probabilities for each class
y_pred_probs = best_model.predict(X_test)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import classification_report

class_names = [
    "Arabic", "Dutch", "English", "French", "German",
    "Italian", "Korean", "Mandarin", "Polish", "Portuguese",
    "Russian", "Spanish", "Turkish"
]

report = classification_report(y_true, y_pred, target_names=class_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       0.95      1.00      0.97       141
#        Dutch       0.98      1.00      0.99       119
#      English       0.97      0.64      0.78       107
#       French       0.95      0.99      0.97       107
#       German       0.98      1.00      0.99       114
#      Italian       0.98      1.00      0.99       119
#       Korean       0.96      1.00      0.98       111
#     Mandarin       0.98      1.00      0.99       124
#       Polish       0.98      1.00      0.99       109
#   Portuguese       0.99      1.00      1.00       104
#      Russian       0.99      1.00      1.00       110
#      Spanish       0.95      0.98      0.97       124
#      Turkish       1.00      1.00      1.00       117
#
#     accuracy                           0.97      1506
#    macro avg       0.97      0.97      0.97      1506
# weighted avg       0.97      0.97      0.97      1506

# %%
# Save the model
best_model.save('cnn_tunning.h5')
loaded_model = load_model('cnn_tunning.h5')
loss, accuracy = loaded_model.evaluate(X_test, y_test)
print("Loaded model accuracy:", accuracy)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.3261
# Loaded model accuracy: 0.9727755784988403

# %%
best_model.save('cnn_tunning_keras.keras')

# %%
from tensorflow.keras.models import load_model

# Load the best model you saved earlier
model = load_model('/kaggle/working/cnn_tunning.h5')

# %%
def preprocess_audio(file_path, target_sample_rate=44100, n_mfcc=13):
    # Load data
    y, sr = librosa.load(file_path, sr=target_sample_rate)

    # Extract MFCC
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)

    # Normalize MFCC
    mfcc = (mfcc - np.mean(mfcc)) / np.std(mfcc)
    mfcc = mfcc.T

    # Get 13 MFCC coefficients
    if mfcc.shape[0] > 13:
        mfcc = mfcc[:13, :]
    else:
        # Padd with zeros if coefficients are less than 13
        mfcc = np.pad(mfcc, ((0, 13 - mfcc.shape[0]), (0, 0)), mode='constant')
    mfcc = np.mean(mfcc, axis=1, keepdims=True)

    # Expand dimensions to match the input shape of the model (batch_size, time_steps, features)
    mfcc = np.expand_dims(mfcc, axis=0)

    return mfcc

# %%
file_path = '/kaggle/input/speech-accent-archive/recordings/recordings/english2.mp3'

# Preprocess the audio
audio_data = preprocess_audio(file_path)
print("Shape of preprocessed audio data:", audio_data.shape)
# Out:
# Shape of preprocessed audio data: (1, 13, 1)

# %%
predictions = model.predict(audio_data)

predicted_class = np.argmax(predictions, axis=1)

class_names = [
    "Arabic", "Dutch", "English", "French", "German",
    "Italian", "Korean", "Mandarin", "Polish", "Portuguese",
    "Russian", "Spanish", "Turkish"
]

print(f"The predicted class for the audio file is: {class_names[predicted_class[0]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# The predicted class for the audio file is: English

# %%
model.save('cnn_tunning.h5')

# %%
import tensorflow as tf
from joblib import load

def load_model(model_name):
    if model_name.endswith('.h5'):
        model = tf.keras.models.load_model(model_name)
    else:
        model = load(f'{model_name}.joblib')
    return model

load_model('/kaggle/working/cnn_tunning.h5')
# Out:
# <Sequential name=sequential_1, built=True>
